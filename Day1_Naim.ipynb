# %%
# Comments
# Comments provides meaningful information about the code
# In Python we can define the comments using #

# %%
# print() function
# print() is a built-in function in python
# used to display the message or a result on a screen

print ("Hello World")
print ('Welcome To The World Of Pyhton 🤖')
print (10+2)
# Out:
# Hello World
# Welcome To The World Of Pyhton 🤖
# 12

# %%
# in order to know the complete summpary of any built-in function
# help(functionName)

help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
print("John","Smith")
# print ("John,"Smith",sep'') meaning this sep is used to add space b/w values
print("John","Smith",sep='🤯')
print("John","Smith",sep='-->')
print ("John","Smith",sep='')
# Out:
# John Smith
# John🤯Smith
# John-->Smith
# JohnSmith

# %%
# end parameter of print () used to add \n at the end of tthe value by default
# \n --> newline \t ---> tabSpace

print("Nexperts") # print("Nexperts",end='\n') Nexperts\n
print("Academy") # Academy\n
print("Python",end='\t') # Python\t
print("Programming") # Programming\n
print("YP AI ML")
# Out:
# Nexperts
# Academy
# Python	Programming
# YP AI ML

# %%
# Variables
# A variable is a container for storing the informatiom

name = "Naim"
age = 29\

print(name,age) # here name and age is the variable
# Out:
# Naim 29

# %%
# Rules For Defining Variables
# Rule 1 : A Variable can not starts with number
# Rule 2 : A Variable can not have a white space
# Rule 3 : Variables are Case Sensitive [recommenndation]
# Rule 4 : Try to avoid using reserved keywords as your variable names
#       print() if else elif for while and or not def
